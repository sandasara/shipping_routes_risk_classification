# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report

import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text

from matplotlib import pyplot as plt
import seaborn as sn
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4712\1299898317.py in <module>
#      11 from textblob import TextBlob
#      12
# ---> 13 import tensorflow as tf
#      14 import tensorflow_hub as hub
#      15 import tensorflow_text as text
#
# ~\anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      43 _tf2.enable()
#      44
# ---> 45 from ._api.v2 import __internal__
#      46 from ._api.v2 import __operators__
#      47 from ._api.v2 import audio
#
# ~\anaconda3\lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py in <module>
#      12 from . import eager_context
#      13 from . import feature_column
# ---> 14 from . import function
#      15 from . import graph_util
#      16 from . import mixed_precision
#
# ~\anaconda3\lib\site-packages\tensorflow\_api\v2\__internal__\function\__init__.py in <module>
#       7
#       8 from tensorflow.python.eager.def_function import Function
# ----> 9 from tensorflow.python.eager.function import defun_with_attributes
#
# ImportError: cannot import name 'defun_with_attributes' from 'tensorflow.python.eager.function' (C:\Users\Dishan\anaconda3\lib\site-packages\tensorflow\python\eager\function.py)

# %%
manual_df = pd.read_excel('C:/Users/Dishan/Vessel tracking project/manually_labeled_data.xlsx')
manual_df
# Out:
#            Date                                              Title  \
# 0    2023-07-26  \nPodcast: In Conversation with Nikeel Idnani ...
# 1    2023-07-26  \nChina Merchants Port and CMA CGM strengthen ...
# 2    2023-07-26  \nCMA CGM Liberty is first LNG-powered boxship...
# 3    2023-07-26      \nCyan Renewables buying first SOV from DEME
# 4    2023-07-26  \nShanghai international trade exceeds $280 bi...
# ..          ...                                                ...
# 688         NaN  2 Long Beach Port terminals close amid labor n...
# 689         NaN  Coastal Cargo lays off its workforce, shuts do...
# 690         NaN  Port of Seattle cargo operations continue afte...
# 691         NaN  LA-LB outlook darkens as labor unrest briefly ...
# 692         NaN  Closure at Long Beach port resulting in trucki...
#
#                                            Description  Risk
# 0    \nThis latest episode of the Seatrade Maritime...   0.0
# 1    \nThe Chinese port operator China Merchants Po...   0.0
# 2    \nThe 15,000 teu CMA CGM Liberty has become th...   0.0
# 3    \nSingapore-based offshore wind farm vessel-op...   0.0
# 4    \nShanghai's total import and export value hit...   0.0
# ..                                                 ...   ...
# 688  LONG BEACH, Calif. - A pair of cargo terminals...   1.0
# 689  The decision was taken to prevent any collisio...   1.0
# 690  The disruption comes after similar work slowdo...   1.0
# 691  The Port of Los Angeles’ sales pitch to import...   1.0
# 692  LONG BEACH, Calif. — A labor dispute at the po...   1.0
#
# [693 rows x 4 columns]

# %%
manual_df['Risk'] = manual_df['Risk'].astype(bool)

# %%
manual_df['Risk'].value_counts()
# Out:
# False    662
# True      31
# Name: Risk, dtype: int64

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\dishan\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\dishan\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: tqdm in c:\users\dishan\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: click in c:\users\dishan\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\dishan\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\dishan\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: colorama in c:\users\dishan\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.5)

# %%
nltk.download('omw-1.4')

# Download necessary resources for NLTK
nltk.download('punkt')
nltk.download('wordnet')

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

# Function to tokenize and lemmatize text
def tokenize_and_lemmatize(text):
    if isinstance(text, str):  # Check if the text is not NaN or missing
        words = word_tokenize(text.lower())
        lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
        return lemmatized_words
    else:
        return []

# Tokenize and lemmatize the 'Title' and 'Description' columns
manual_df['Title'] = manual_df['Title'].apply(tokenize_and_lemmatize)
manual_df['Description'] = manual_df['Description'].apply(tokenize_and_lemmatize)
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Dishan\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dishan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Dishan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
manual_df
# Out:
#            Date                                              Title  \
# 0    2023-07-26  [podcast, :, in, conversation, with, nikeel, i...
# 1    2023-07-26  [china, merchant, port, and, cma, cgm, strengt...
# 2    2023-07-26  [cma, cgm, liberty, is, first, lng-powered, bo...
# 3    2023-07-26  [cyan, renewables, buying, first, sov, from, d...
# 4    2023-07-26  [shanghai, international, trade, exceeds, $, 2...
# ..          ...                                                ...
# 688         NaN  [2, long, beach, port, terminal, close, amid, ...
# 689         NaN  [coastal, cargo, lay, off, it, workforce, ,, s...
# 690         NaN  [port, of, seattle, cargo, operation, continue...
# 691         NaN  [la-lb, outlook, darkens, a, labor, unrest, br...
# 692         NaN  [closure, at, long, beach, port, resulting, in...
#
#                                            Description   Risk
# 0    [this, latest, episode, of, the, seatrade, mar...  False
# 1    [the, chinese, port, operator, china, merchant...  False
# 2    [the, 15,000, teu, cma, cgm, liberty, ha, beco...  False
# 3    [singapore-based, offshore, wind, farm, vessel...  False
# 4    [shanghai, 's, total, import, and, export, val...  False
# ..                                                 ...    ...
# 688  [long, beach, ,, calif., -, a, pair, of, cargo...   True
# 689  [the, decision, wa, taken, to, prevent, any, c...   True
# 690  [the, disruption, come, after, similar, work, ...   True
# 691  [the, port, of, los, angeles, ’, sale, pitch, ...   True
# 692  [long, beach, ,, calif., —, a, labor, dispute,...   True
#
# [693 rows x 4 columns]

# %%
output_file='manually_labeled_lemmatized_data.xlsx'
manual_df.to_excel(output_file, index=False)

# %%
vec_tdidf = TfidfVectorizer()

# %%
X_title = manual_df['Title']
X_description = manual_df['Description']
y = manual_df['Risk']

# %%
# Assuming X_title and X_description are lists of text documents
X_title = [' '.join(document) for document in X_title]  # Convert lists to strings
X_description = [' '.join(document) for document in X_description]

# %%
X_title
# Out:
# ['podcast : in conversation with nikeel idnani from imarest uae branch',
#  'china merchant port and cma cgm strengthen collaboration',
#  'cma cgm liberty is first lng-powered boxship to call in japan',
#  'cyan renewables buying first sov from deme',
#  'shanghai international trade exceeds $ 280 billion in h1',
#  'poor socio-economic condition , climate change likely driving se asia ship robbery',
#  'engie to boost decarbonization of sea transport',
#  'fincantieri , rina team up with newcleo to test feasibility of nuclear naval propulsion',
#  'record high officer supply shortfall threatens manning cost , warns drewry',
#  'h2u , vopak to work on gladstone green hydrogen and ammonia export project',
#  'hmm ’ s vessel cruise comfortably within cii regulation',
#  'ibia and green marine to develop methanol bunkering training programme',
#  'nyk line welcome fifth lng-powered car carrier',
#  'wan hai line opts for $ 96mln sustainability-linked financing',
#  'eps and china power ally on green energy solution for maritime industry',
#  'singapore ready for it 1st methanol bunkering op',
#  'with salvage ops underway , dutch govt urged to step in for ‘ safe and environmentally sound ’ fso recycling',
#  'with peak oil demand in sight , is the end of the black gold era really approaching ?',
#  'eec express interest in recycling fso safer',
#  'japan set to install zero emission charger for ship in hanshin port and keihin port',
#  'jr shipping outfit 9th vessel with carbon capture tech',
#  'x-press feeder welcome scrubber-fitted mid-size boxship into the fleet',
#  'ineos charter two lng carrier newbuilds from mol',
#  'china ’ s new international land-sea corridor join gsbn',
#  'china ’ s new international land-sea corridor join gsbn',
#  'podcast : in conversation with nikeel idnani from imarest uae branch',
#  'china merchant port and cma cgm strengthen collaboration',
#  'photo : world ’ s 1st green methanol-fuelled boxship arrives in singapore for bunkering',
#  'fremantle highway fire rage on near unesco heritage site',
#  'hyundai samho launch lng carrier energy fortitude for alpha gas',
#  'china ’ s first methanol bunkering ship get green light',
#  'flagship founder and signal team up on maritime start-ups',
#  'sungas to invest $ 2 bln in green methanol plant to power maersk ’ s ship',
#  'hudong-zhonghua lock in new order to build lng carrier duo for cosco , cnpc',
#  'ayk energy open new unit , one of first order to go for h2-run vessel retrofit',
#  'hudong-zhonghua win nod for three ship design',
#  'ab greenlights ammonia-fueled containership design by seaspan and partner',
#  'gsi name and delivers lng-ready msc noa ariela',
#  'hd ksoe score $ 140mln deal to build product carrier duo',
#  'gtt win classnk ’ s approval for new liquefied hydrogen tank concept',
#  'engie to boost decarbonization of sea transport',
#  'fincantieri , rina team up with newcleo to test feasibility of nuclear naval propulsion',
#  'with salvage ops underway , dutch govt urged to step in for ‘ safe and environmentally sound ’ fso recycling',
#  'with peak oil demand in sight , is the end of the black gold era really approaching ?',
#  'eec express interest in recycling fso safer',
#  'finnlines take delivery of 1st hybrid superstar ro-pax vessel',
#  'japan set to install zero emission charger for ship in hanshin port and keihin port',
#  'jr shipping outfit 9th vessel with carbon capture tech',
#  'x-press feeder welcome scrubber-fitted mid-size boxship into the fleet',
#  'sea-lng : bio-lng bunkering is available in almost 70 location',
#  'photo : world ’ s 1st green methanol-fuelled boxship arrives in singapore for bunkering',
#  'four contender join the race for hmm ’ s privatization',
#  'world ’ s largest double-ended hybrid ferry named in uk',
#  'singapore carry out first ship-to-ship methanol bunkering for maersk',
#  'video : fire continues to rage on car carrier fremantle highway',
#  'singapore carry out first ship-to-ship methanol bunkering for maersk',
#  'china ’ s new international land-sea corridor join gsbn',
#  'fourth lng dual-fuel vlcc join maran tanker fleet',
#  'oci global to supply x-press feeder with green methanol',
#  'ocean giant unite to forge mega fleet of semi-submersible vessel',
#  'hd hhi ’ s ammonia-based ship hvac refrigeration system get green light from ab',
#  'safe bulkers welcome 4th newbuild , advance eco upgrade',
#  'sea-lng : bio-lng bunkering is available in almost 70 location',
#  'photo : world ’ s 1st green methanol-fuelled boxship arrives in singapore for bunkering',
#  'four contender join the race for hmm ’ s privatization',
#  'world ’ s largest double-ended hybrid ferry named in uk',
#  'fremantle highway fire rage on near unesco heritage site',
#  'hyundai samho launch lng carrier energy fortitude for alpha gas',
#  'china ’ s first methanol bunkering ship get green light',
#  'flagship founder and signal team up on maritime start-ups',
#  'sungas to invest $ 2 bln in green methanol plant to power maersk ’ s ship',
#  'hudong-zhonghua lock in new order to build lng carrier duo for cosco , cnpc',
#  'ayk energy open new unit , one of first order to go for h2-run vessel retrofit',
#  'with salvage ops underway , dutch govt urged to step in for ‘ safe and environmentally sound ’ fso recycling',
#  'with peak oil demand in sight , is the end of the black gold era really approaching ?',
#  'eec express interest in recycling fso safer',
#  'finnlines take delivery of 1st hybrid superstar ro-pax vessel',
#  'japan set to install zero emission charger for ship in hanshin port and keihin port',
#  'x-press feeder welcome scrubber-fitted mid-size boxship into the fleet',
#  'video : fire continues to rage on car carrier fremantle highway',
#  'singapore carry out first ship-to-ship methanol bunkering for maersk',
#  'china ’ s new international land-sea corridor join gsbn',
#  'fourth lng dual-fuel vlcc join maran tanker fleet',
#  'oci global to supply x-press feeder with green methanol',
#  'ocean giant unite to forge mega fleet of semi-submersible vessel',
#  'hd hhi ’ s ammonia-based ship hvac refrigeration system get green light from ab',
#  'safe bulkers welcome 4th newbuild , advance eco upgrade',
#  'sea-lng : bio-lng bunkering is available in almost 70 location',
#  'photo : world ’ s 1st green methanol-fuelled boxship arrives in singapore for bunkering',
#  'four contender join the race for hmm ’ s privatization',
#  'world ’ s largest double-ended hybrid ferry named in uk',
#  'fremantle highway fire rage on near unesco heritage site',
#  'hyundai samho launch lng carrier energy fortitude for alpha gas',
#  'china ’ s first methanol bunkering ship get green light',
#  'flagship founder and signal team up on maritime start-ups',
#  'sungas to invest $ 2 bln in green methanol plant to power maersk ’ s ship',
#  'hudong-zhonghua lock in new order to build lng carrier duo for cosco , cnpc',
#  'ayk energy open new unit , one of first order to go for h2-run vessel retrofit',
#  'with salvage ops underway , dutch govt urged to step in for ‘ safe and environmentally sound ’ fso recycling',
#  'with peak oil demand in sight , is the end of the black gold era really approaching ?',
#  'eec express interest in recycling fso safer',
#  'finnlines take delivery of 1st hybrid superstar ro-pax vessel',
#  'japan set to install zero emission charger for ship in hanshin port and keihin port',
#  'jr shipping outfit 9th vessel with carbon capture tech',
#  'x-press feeder welcome scrubber-fitted mid-size boxship into the fleet',
#  'x-press feeder ink green methanol fuel deal with oci',
#  'worker dy in construction of singapore ’ s tuas port phase 2',
#  'hanwha ocean bag new lng carrier order worth $ 260 million',
#  'colossal 24k teu boxship msc mette join msc ’ s fleet',
#  'growing number of lpg tanker adding ammonia to cargo',
#  'fuelng venosa performs cool-down ops for pan ocean ’ s newest lng bunker ship',
#  'ad port and saab uae join hand on port efficiency and safety',
#  'eu expands list of approved ship recycling yard',
#  'siglar carbon partner with lseg on emission reduction tool',
#  'cyan renewables to build offshore wind vessel at china merchant shipyard',
#  'maersk ranked a fastest growing logistics brand',
#  'cyan renewables to build offshore wind vessel at china merchant shipyard',
#  'yanmar commercial launch of hydrogen fuel cell for ship',
#  'maersk ranked a fastest growing logistics brand',
#  'video : fire ravaged fremantle highway arrives at temporary anchorage',
#  'x-press feeder ink green methanol fuel deal with oci',
#  'procopiou ’ s sea trader ink massive bulker deal with cssc',
#  'hapag-lloyd wrap up sm saam terminal business acquisition',
#  'himalaya shipping see first lng bunkering of it newbuild ship',
#  'ocean yield invests in four methanol-ready lr1 product tanker',
#  'cbh join blue visby consortium to support decarbonisation solution',
#  'cc present new lng-powered chuanjiang standard bulk carrier',
#  'deltamarin bag deal for pctc design with alternative fuel',
#  'mol , kddi to trial starlink on ferry , cruise ship and coastal roro vessel',
#  'cma cgm turn to wärtsilä for methanol-fuelled auxiliary engine',
#  'climeon ’ s heat recovery tech picked for maersk ’ s methanol-fueled boxships',
#  'cosco shipping ’ s electric containership hit the water',
#  'tata steel pick lng-fueled mv ubuntu unity to transport it cargo',
#  'hanwha ocean bag new lng carrier order worth $ 260 million',
#  'colossal 24k teu boxship msc mette join msc ’ s fleet',
#  'growing number of lpg tanker adding ammonia to cargo',
#  'fuelng venosa performs cool-down ops for pan ocean ’ s newest lng bunker ship',
#  'ad port and saab uae join hand on port efficiency and safety',
#  'eu expands list of approved ship recycling yard',
#  'siglar carbon partner with lseg on emission reduction tool',
#  'with salvage ops underway , dutch govt urged to step in for ‘ safe and environmentally sound ’ fso recycling',
#  'with peak oil demand in sight , is the end of the black gold era really approaching ?',
#  'eec express interest in recycling fso safer',
#  'finnlines take delivery of 1st hybrid superstar ro-pax vessel',
#  'japan set to install zero emission charger for ship in hanshin port and keihin port',
#  'jr shipping outfit 9th vessel with carbon capture tech',
#  'x-press feeder welcome scrubber-fitted mid-size boxship into the fleet',
#  'maersk see global container volume slump of up to 4 % this year',
#  'maersk see global container volume slump of up to 4 % this year',
#  'china merchant and minsheng logistics sign auto logistics agreement',
#  'greek supplier in energy-saving device assessment agreement with dnv',
#  'damen ink contract with feyz for combi freighter trio',
#  'norden take stake in biofuel developer mash make',
#  'fire damaged fremantle highway at anchor off the netherlands',
#  'world ’ s largest lng bunkering vessel refuels first vlcc',
#  'hd ksoe to build lng carrier pair under $ 530 million deal',
#  'seven company team up on carbon capture and storage project in japan',
#  'a flurry of order continues into summer with tanker leading the charge',
#  'norden buy into danish-indian biofuel scale-up to strengthen future supply',
#  "procopiou 's sea trader ink massive bulker deal with cssc",
#  'hapag-lloyd wrap up sm saam terminal business acquisition',
#  'with salvage ops underway , dutch govt urged to step in for ‘ safe and environmentally sound ’ fso recycling',
#  'with peak oil demand in sight , is the end of the black gold era really approaching ?',
#  'finnlines take delivery of 1st hybrid superstar ro-pax vessel',
#  'japan set to install zero emission charger for ship in hanshin port and keihin port',
#  'jr shipping outfit 9th vessel with carbon capture tech',
#  'x-press feeder welcome scrubber-fitted mid-size boxship into the fleet',
#  'market normalization hit maersk ’ earnings a demand woe and phasing in massive orderbook challenge loom',
#  'tge marine wrap up gas trial on vlgc gas neptune',
#  'clean energy vessel propel yangzijiang ’ s soaring orderbook',
#  'fire-stricken fremantle highway safely reach port of refuge in eemshaven',
#  '2nd lng-fueled 23,600 teu behemoth join hapag-lloyd ’ s fleet',
#  "world 's largest lng bunkering vessel refuels first vlcc",
#  'hd ksoe to build lng carrier pair under $ 530 million deal',
#  'mol advance wind hunter project',
#  'yanmar boost maritime decarbonization with hydrogen fuel cell system',
#  'seven company team up on carbon capture and storage project in japan',
#  'a flurry of order continues into summer with tanker leading the charge',
#  'with salvage ops underway , dutch govt urged to step in for ‘ safe and environmentally sound ’ fso recycling',
#  'with peak oil demand in sight , is the end of the black gold era really approaching ?',
#  'eec express interest in recycling fso safer',
#  'gsi name and delivers lng-ready msc noa ariela',
#  'finnlines take delivery of 1st hybrid superstar ro-pax vessel',
#  'japan set to install zero emission charger for ship in hanshin port and keihin port',
#  'jr shipping outfit 9th vessel with carbon capture tech',
#  'maersk warns of slower demand for container shipping',
#  'all road lead valaris to ‘ strong and sustained upcycle ’',
#  'adnoc ’ s decarbonisation journey pick up speed with new net-zero target',
#  'viking and acorn picked a two new cluster to expand uk ’ s carbon capture and storage industry',
#  'north sea gas support both energy security and net-zero goal , say uk regulator',
#  'ficep : a single partner for all production technology in area 1. the mission is to enhance the productivity of wind tower and foundation fabricator',
#  'rapid development in offshore market require new production method for fast crew supplier',
#  'going with the flow – damen concept aim to tackle the next generation of offshore wind',
#  'lower oil & gas price take a bite out of norwegian energy giant ’ s profit',
#  'court fight on uk govt ’ s hand over oil & gas licensing round',
#  'net-zero puzzle need multiple piece in place : tripling renewables and slashing oil & gas emission',
#  'maersk warns of slower demand for container shipping',
#  'transocean ’ s plethora of new rig deal fetch $ 1.2 billion',
#  'europe redraws black gold map with pool of top oil producer',
#  'seavolt partner set to launch offshore solar platform in the north sea',
#  'iea : ensuring gas supply security and decarbonisation high on global energy market ’ s agenda',
#  'one of uk ’ s largest undeveloped oil field put on hiatus once again',
#  'propulsion fit for the future',
#  'a the offshore drilling market tightens , what ’ s up with the semi-sub rig fleet ?',
#  'ocean current energy is the third source',
#  'ithaca , aker solution , expro , proserv , and ey back 10-point plan to improve north sea worker ’ mental health',
#  'with salvage ops underway , dutch govt urged to step in for ‘ safe and environmentally sound ’ fso recycling',
#  'u spur zest far beyond it border for ccus a ‘ critical ’ decarbonisation tool',
#  '‘ first producing asset ’ on the horizon , a longboat snatch up stake in two north sea oil & gas field',
#  'what will two upcoming giant oil & gas development in the north sea bring ?',
#  'with carbon storage and renewables , totalenergies and petronas driving energy transition forward',
#  'bp , ørsted reach agreement on project overlap area in uk',
#  'woodmac pinpoint five global energy transition theme through asian lens',
#  'eni and vår energi scoop up neptune for $ 4.9 billion',
#  'searenergy and assc bring “ spirit of emden ” into service – offering cargo run in the german north sea',
#  'what are the key tool in uk and norway ’ s energy transition ?',
#  'headway made in bonn but all hope rest on cop28 ’ s shoulder to tackle emission reduction challenge',
#  'with peak oil demand in sight , is the end of the black gold era really approaching ?',
#  'eec express interest in recycling fso safer',
#  'uk ’ s tax change : first step to ‘ restore confidence ’ in oil & gas sector and safeguard energy security',
#  'haptic control development for mechatronic device',
#  'the pioneer of offshore engineering',
#  'how clarksons help offshore wind developer to understand the local marketplace',
#  'north sea oil & gas project with $ 14.9 billion investment tag inch closer to green light',
#  'kongsberg enriches new ship design with methanol & ammonia',
#  'natural gas hailed a the backbone of global energy mix',
#  'boskalis vessel come to ward off decaying oil tanker threat',
#  'clean energy spending overtakes fossil fuel investment',
#  'g7 upping the green and low-carbon ante while gas is still king of energy throne',
#  'decom market re-shuffled by ukraine war : postponement and delay',
#  'shelf drilling ceo : rising rig demand in asia to propel day rate to new height',
#  'eu signal readiness to scale up methane menace mitigation',
#  'new job for diamond offshore ’ s rig fleet in u.s. and uk',
#  'longboat and japan ’ s japex set on creating ‘ leading norwegian-focussed independent ’',
#  'uk politician see collaboration with oil & gas sector a key to reaching net-zero',
#  'sbm offshore ink new deal with exxonmobil for guyana fpso fleet',
#  'eu set the stage to throw fossil energy import into it methane emission regulation',
#  'climate goal : wait for a stricter agreement or take responsibility ?',
#  'will the eu let methane emission slip through the crack ?',
#  'rig deal lift transocean ’ s total backlog to $ 8.6 billion',
#  'pushing the limit of offshore wind farm installation and transportation',
#  'bp cheer first oil from it new deepwater gulf of mexico platform',
#  'giant in germany lining up to buy offshore wind power',
#  'which country is the preferred global oil supplier ?',
#  'ieefa warns cc will worsen inflation in power sector',
#  '$ 35 trillion energy transition bill for 1.5°c climate target',
#  '2022 push ccus to new height',
#  'turning brazil into world ’ s fourth largest oil producer',
#  'france creates largest european sea trial center for marine renewables',
#  'totalenergies ramping up low-carbon energy in 2023',
#  'what are key area the u.s. need to jump-start on the road to net-zero by 2050 ?',
#  'offshore drilling upcycle whets appetite for stacked rig',
#  'taking the maritime and offshore industry by storm',
#  'eia call for new approach : throwing carbon price into the mix to unveil fossil fuel subsidy',
#  'two sbm offshore ’ s fpsos slated for first oil in 2023',
#  'eu-scores : win-wins of offshore energy multi-use park',
#  'peak in fossil fuel emission anticipated by 2025',
#  'key regulatory approval in place for dorado oil project development and sanctioning',
#  'transocean strike multiple rig deal with total backlog of $ 1.9 billion',
#  'severstal keep focus on offshore project',
#  'watch : activist board boskalis vessel carrying shell ’ s north sea-bound fpso',
#  'turning depleted gas field into carbon storage cluster',
#  'westwood : 2023 shaping up to be a busy year for offshore rig with further boost in day rate',
#  'guyana & bakken getting lion ’ s share of hess ’ budget boost once again',
#  'registration open for offshore energy 2021',
#  'new fpso set sail for bp ’ s giant gas project',
#  'watch : shetlanders urge norway to stop huge oil & gas project',
#  'low-carbon investment set to hit $ 620 billion in 2023 , rystad say',
#  'shell unveils five energy sector trend to watch in 2023',
#  'noble , halliburton and odfjell forge five-year rig alliance with aker bp for drilling ops',
#  'usa : to drill or not to drill ?',
#  'uk firm emerges from bankruptcy',
#  'jack-up rig kick off drilling campaign off gabon',
#  'norway to keep boosting europe ’ s energy security with high gas export in 2023',
#  'uae ’ s oil & gas giant earmark $ 15 billion for low-carbon project',
#  'faccin wind tower division : a reliable partner for your wind energy project',
#  'maritime insurance market update , q3 2020',
#  'energy outlook : oil making a comeback in 2023 , say woodmac',
#  '2022 in review : some of the major incident related to offshore oil & gas',
#  'breathing new life into oil rig',
#  '2022 is a wrap : highlight from the offshore energy industry',
#  'while exxonmobil take legal action , european commission claim oil & gas windfall tax ‘ fully compliant with eu law ’',
#  'four missing after chopper go down in gulf of mexico while departing from oil rig',
#  'op-ed : tony lewis on the exciting potential of wave energy',
#  'bp ’ s giant incoming hydrocarbon project to watch in 2023',
#  'price cap on russian crude oil come into force while opec+ stick to output cut',
#  'africa turning into hotspot for oil & gas exploration',
#  'more gulf of mexico work for seadrill rig',
#  'how is the transition to renewables faring in the midst of a global energy crisis ?',
#  'more north sea rig heading for greener pasture next year',
#  'how do thing stand for the oil & gas industry in the wake of cop27 ?',
#  'green h2 plan lead to first offshore wind leasing in canada',
#  'new dutch donation for fso salvage ops in red sea',
#  'two contrasting scenario depict challenge to net-zero by 2050 amid energy crisis',
#  'employment in clean energy sector on the rise , exceeding decline in fossil fuel job , say iea',
#  'rystad : oil & gas exploration on the decline with global awarded acreage near all-time low',
#  'availability of carbon-neutral fuel will be a big problem',
#  'new baltic sea plan to help avoid reliance on russian fuel',
#  'inpex , woodside , totalenergies to explore hub potential for ‘ one of the largest cc project in the world ’',
#  'to extend or end a ship ’ s life ?',
#  'wa maritime industry too quick to discard nuclear power ?',
#  'rystad : 2022 high-impact oil & gas drilling activity on track to yield ‘ one of the most productive annual volume ’',
#  'dorado delayed amid inflation and supply chain uncertainty',
#  'u.s. energy bill win over environmentalist but not oil & gas lobby',
#  'sanctions-induced setback in sourcing good sour russia-iran $ 40 bln deal , say rystad',
#  'rystad : u.s. bill to bolster energy security with no respite for industry cost in sight',
#  'equinor file key document ahead of plan to invest billion in uk oil and gas project',
#  "u.s. climate bill 'does not shut off fossil fuel '",
#  'westwood see five-year offshore epc spend reaching whopping $ 276 billion',
#  'uk tidal energy expert call for more support from government',
#  'red alert for eu : how can europe prevent a major gas crunch ?',
#  'rig utilisation ramp up in asia pacific , reveals westwood',
#  'amid high fossil fuel price , renewable power save around $ 55 bln , say irena',
#  'a merger with lundin go into effect , aker bp unveils plan to spend over $ 15 bln on project',
#  'faster ramp-up of investment needed to tackle double whammy of energy and climate crisis',
#  'simec atlantis post €86 million loss for ‘ challenging ’ 2021',
#  'un coordinator urge public to help stave off ‘ 5th largest oil spill from a tanker in history ’',
#  'non-opec+ to spearhead global oil supply in 2023',
#  'driven by the big ban , lng growth and energy transition to pick up speed – woodmac',
#  'environmental group starting legal action to end support for 30 eu-backed gas project',
#  'german industry call for €10bn push for offshore green h2',
#  'g7 country to end public funding for international fossil fuel project',
#  'op-ed : tidal wave tapping into flow of capital',
#  'german chancellor ’ s africa tour seen a critical step to energy security',
#  'germany talk gas project with senegal',
#  'offshore wind target to fuel repowereu green hydrogen plan',
#  'westwood : offshore rig utilisation even higher than reported',
#  'world-class tidal blade test facility open for business in scotland',
#  'turkey awaits arrival of it fourth drillship',
#  'new gas discovery for energean off israel',
#  'petrobras to invest $ 16 bln to revamp campos basin',
#  'germany charter four fsrus , cutting dependence on russia',
#  'wintershall dea ’ s hydrogen and cc project to support wilhelmshaven energy hub',
#  'eu move to ban russian oil import',
#  'new north sea project targeting 1.3 bln barrel of o & g',
#  'bw offshore say india yard incident unrelated to it vessel',
#  'sembmarine and keppel o & m seal the deal',
#  'germany looking to drill for gas in north sea',
#  'u step up effort to enable green shipping corridor',
#  'ithaca add 4 of uk ’ s largest oil & gas field to portfolio',
#  'eu ban russian vessel from port , ‘ edge closer ’ to banning russian oil import',
#  "fifth release of emergency oil reserve in iea 's history",
#  'biden order the largest release of oil reserve in history',
#  'activist demand immediate halt to new fossil fuel project',
#  'answer to energy security lie in energy transition - report',
#  "heerema 's giant crane vessel switch to green shore power",
#  '9+ gw of new offshore wind capacity under review in taiwan',
#  'bp and eni poised to create angola ’ s largest producer',
#  'maersk secures green fuel supply for methanol-fueled ship',
#  'ocean energy back on track , oee statistic show',
#  'u.s. ban russian oil , lng , and coal import while uk move to phase out russian oil import',
#  'oil price jump a sanction spur supply fear while opec+ reconfirms output plan',
#  'container shipping company halt shipment to russia',
#  'u.s. and 30 iea ally to release 60 million barrel of oil',
#  'shell ditching russia business and total withholding capital',
#  'bp to get rid of it interest in russia ’ s rosneft and equinor to exit russian jv',
#  'germany to break free from russian gas with 2 lng terminal',
#  'oil price soar past $ 100 mark a russia-ukraine crisis escalates',
#  'talos reach another cc milestone with large-scale carbon sequestration hub',
#  'hapag-lloyd to deploy first 23,500+ teu ship in 2023',
#  'six key offshore wind theme to watch in 2022 – westwood',
#  'top energy transition trend to watch in 2022 , a seen by westwood',
#  'middle east facing uphill battle to meet net-zero , s & p global platts say',
#  'russia ’ s oil output to rise by 5 per cent in 2022',
#  'southeast asia ’ s oil & gas output unlikely to exceed 5 million boepd , rystad say',
#  'maersk drilling ink rig renewal deal worth around $ 1 bln with aker bp',
#  'bp pick contractor for uk ’ s landmark carbon capture and storage cluster prize',
#  'john fredriksen firm take interest in valaris',
#  'danish govt bankroll two co2 storage scheme in north sea',
#  'uk port set for revival with plan to recycle old rig into foundation for floating wind farm',
#  'panama canal introduces 1st ghg emission fee',
#  'soaring oil & gas demand to catapult well intervention over $ 14 billion by 2031 , fact.mr say',
#  'biden on a mission to combat rising energy price and lack of supply by tapping into oil reserve',
#  'jersey add new board member to expedite growth plan',
#  'unctad : maritime trade growth to slow down in coming year',
#  "oxagon , world 's largest floating industrial complex unveiled",
#  'totalenergies ’ well flow test off suriname support hope for oil development hub',
#  'cop26 end with ‘ weak and compromised ’ line on phasing down fossil fuel',
#  'draft cop26 call for phasing out fossil fuel subsidy',
#  'noble shareholder voice concern over maersk merger plan',
#  'shelf drilling expects improvement in global jack-up demand and pricing',
#  'maersk drilling to merge with noble',
#  'baker hughes and shell unite to speed up energy transition',
#  'biden in ‘ historic action ’ to cut methane emission from oil & gas operation',
#  'international consortium unveils £1.7b tidal lagoon plan for swansea',
#  'uk unveils net-zero strategy ahead of cop26',
#  'two uk carbon capture and storage project selected for state funding',
#  'shell exit permian a energy transition play out',
#  'houston reimagining meaning of energy capital of the world',
#  'aker bp hand out first major contract for north sea development',
#  'maersk order carbon-neutral methanol-powered fleet',
#  'where will cuba accusation lead cma cgm business ?',
#  'major uk project to unlock untapped potential of ocean renewable energy fuel',
#  'eu revise ets to include shipping sector',
#  'suriname show potential to become next oil hot spot , globaldata say',
#  'meygen delivers record-breaking 37gwh to uk grid a simec atlantis trim year-end loss',
#  'contractor pipeline to double a fpso market is booming , rystad say',
#  'ammonia can fully develop it climate protection potential',
#  'keppel and sembcorp marine confirm merger talk entry',
#  'interview with fulco vrooland : rohr-idreco is on the rise',
#  'transocean delay delivery for the world ’ s first 8th gen ultra-deepwater drillships',
#  'ship reshuffle a wind farm off taiwan nears construction',
#  'mission innovation 2.0 to spearhead $ 250 billion clean energy innovation decade',
#  'repair on johan castberg fpso hull to delay completion by a year',
#  'uk : new scheme emerges for rapid decarbonisation of oil & gas asset with floating wind and hydrogen',
#  'borr upbeat about market amid strong tendering and contracting activity',
#  'spanish-japanese company unveils 500 mw floating wind plan',
#  'korea to build offshore h2 plant powered by floating wind',
#  'new offshore wind era dawn in france',
#  'deep sea mining robot get stuck 4,500 metre beneath pacific ocean ’ s surface',
#  'giignl : lng import edged up 0.4 pct in 2020',
#  'woodmac : asia reshaped lng market within a year',
#  'equinor investigating welding defect on castberg fpso hull',
#  'in focus : piecing together the energy transition puzzle',
#  'lng a fuel should be a no-brainer . so , what ’ s the hold-up ?',
#  'can european fleet be made greener ?',
#  'ever given refloated after a week of blocking ship in the suez',
#  'one of the world ’ s largest containership block suez canal',
#  'uk pledge not to leave oil & gas worker behind a landmark north sea transition deal is agreed',
#  'three noble rig coming back from warm-stack for new gig',
#  'exxonmobil curb spending plan , reveals path to lower-carbon future',
#  'state oil firm might waste $ 400b a energy shift speed up',
#  "u.s. energy secretary nominee back biden 's green push",
#  'offshore wind need to wake up to benefit of digitalisation',
#  'keppel to exit offshore rig building to position for energy transition',
#  'biden halt federal oil and gas leasing indefinitely',
#  'norway eyeing deep-sea metal mining future instead of oil',
#  'uk to end support for oil and gas project overseas',
#  "offshore wind , green hydrogen backbone of eu 's 2050 goal",
#  "environmentalist blast imo 's lack of ambition",
#  'biden win could benefit short-term oil demand',
#  'biden to steer u.s. off oil to tackle climate change',
#  'china going carbon neutral : what will it mean for shipping ?',
#  "japan 's offshore wind ambition attracting major developer",
#  'elliott attempting to stop chevron ’ s buy of noble energy',
#  'rystad : giant tuna-1 discovery could save turkey $ 21b',
#  'turkey to continue exploring disputed area in mediterranean',
#  'digital twin for the maritime sector',
#  'climate change target on ogci , shell , and biden ’ s menu',
#  'allianz : 14 big ship lost in asian water in 2019',
#  'crew repatriation : the brighter side of thing',
#  "uk 's o & g industry pledge to halve emission by 2030",
#  'first monopile-caisson foundation installed at owf in china',
#  'covid-19 and offshore construction',
#  'holland america ’ s 2 ship pas panama canal after 4 death on board zaandam',
#  'energy security is undoubtedly a key issue',
#  'dutch steel : manufacturer geared up for offshore wind',
#  'big data in offshore wind',
#  'saint-brieuc case : na & wind dispute award decision',
#  'the road to renewables',
#  'safe , cost-effective installation start with deck layout',
#  'several box to tick when looking for vessel design',
#  'sbm offshore : floating wind technology is the future',
#  'floating wind-powered water injection',
#  'showcased during windenergy hamburg',
#  'germany update',
#  "vattenfall 's surveillance centre",
#  "outlining deutsche windtechnik 's approach",
#  'construction phase united kingdom',
#  'offshore construction : it take a giant to know a giant',
#  'finance : small player – big project',
#  'crane : huisman delivers world ’ s largest leg encircling crane',
#  'wtivs : wind turbine installation vessel : new optimism',
#  'windfarm update : french owf project , wikinger , borkum riffgrund 2 , butendiek , galloper',
#  'windfarm update : amrumbank , global tech i , borkum west 2.1 , dolwin beta , ostwind 1',
#  'windfarm update : race bank , rampion , walney extension , enbw baltic 2 , gode wind 1 & 2 , sandbank',
#  'scaldis smc : lifting at a higher level',
#  'offshore interconnectors : the german offshore grid update',
#  'the foundation of the industry : the next generation',
#  'accommodation vessel : the past , present and the future',
#  'wind farm update',
#  'wind farm update',
#  'wind farm update',
#  'wind farm update',
#  'wind farm update',
#  'accommodation at sea – comfort at sea for optimal workforce efficiency part 1 : temporary living quarter',
#  'wind farm support vessel : the class of 26',
#  'real-time feedback enables learning on the job : how vessel display make maintenance safer , faster and cost effective',
#  'maritime holland : renewed class of energy',
#  'unexploded ordnance ( uxo ) : unexploded ordnance doe not go away',
#  'subsea protection : protection solution against scouring',
#  'update on france : the great potential of offshore wind in france',
#  'edf energy nouvelles : france can now be part of the offshore wind story',
#  'improving subsea cable detection',
#  'offshore wind support scheme : current status of european support scheme',
#  'connecting offshore wind farm : tso tennet us german experience for dutch offshore challenge',
#  'eneco : touring the dutch offshore wind farm',
#  'windfarm update : global tech i',
#  'windfarm update : belwind & northwind',
#  'dong energy in norddeich , germany : building the o & m base for the borkum riffgrund and gode wind project',
#  'vattenfall : dantysk – discovering best practises',
#  'uk round 3 : accepting the challenge',
#  'wind farm support vessel : the lifeblood of a wind farm',
#  'bow terminal : a heavy-lift port',
#  'iberdrola : fighting the challenge in developing offshore wind',
#  'oil & gas versus wind : fabricom offshore service',
#  'oil & gas versus wind : found ocean',
#  'europe update : first half year give mixed image for offshore wind',
#  'wtivs : the future – an owner/operator ’ s perspective',
#  'deme group : aiming at full presence in offshore wind',
#  'siemens wind power',
#  'vsmc',
#  'mecal',
#  'offshore engineering centre : a complete package from abb',
#  'weather data : forecasting for cost reduction',
#  'gamesa : ready to go offshore',
#  'sif group',
#  'bladt industry a/s',
#  'unmanned aerial vehicle : safe air inspection',
#  'corrosion and fouling prevention',
#  'wind farm support vessel',
#  'fred . olsen united : staying ahead of the game',
#  'blrt grupp : nordic baltic shipyard show green power',
#  'noise mitigation system : first commercial operation…',
#  'subsea operation – an overview',
#  'wind banker iii : meewind',
#  'wind banker iii : green giraffe energy banker',
#  'wind banker iii : pensiondanmark',
#  'floating wind turbine : a promising start',
#  'owi-lab : room for efficiency , reliability and cost efficiency',
#  'hollandia fabrication yard',
#  'g & g international',
#  'wtivs',
#  'iberdrola : a spanish giant succeeding offshore',
#  'ready for take off : helicopter in the offshore wind industry',
#  'port of wilhelmshaven : fit for the future',
#  'port of emden : homeport for wind energy',
#  '“ offshore substation should have a standard size of 900mw ”',
#  'learning from each other : the uk and germany need to work together',
#  'fraunhofer iwes director expects : “ wind will become one of the cheapest resource ”',
#  'france : round 1',
#  'building for the future : keppel pel',
#  'offshore blade : the cutting edge – lm wind power',
#  'diving deeper for offshore wind',
#  'wind farm support vessel : the operator',
#  'wind farm support vessel : the builder',
#  'offshore wind rule ‒ det norske veritas',
#  'offshore wind in france – the state of the industry',
#  'the marineco mariah',
#  'grid ‒ paving the way forward',
#  'xiamen port ink cooperation agreement with psa in singapore',
#  'maersk see global container volume slump of up to 4 % this year',
#  'dry bulk stock and the dog day of summer',
#  'xiamen port ink cooperation agreement with psa in singapore',
#  'all road lead valaris to ‘ strong and sustained upcycle ’',
#  'adnoc ’ s decarbonisation journey pick up speed with new net-zero target',
#  'viking and acorn picked a two new cluster to expand uk ’ s carbon capture and storage industry',
#  'north sea gas support both energy security and net-zero goal , say uk regulator',
#  'ficep : a single partner for all production technology in area 1. the mission is to enhance the productivity of wind tower and foundation fabricator',
#  'rapid development in offshore market require new production method for fast crew supplier',
#  'eni ’ s profit cut nearly in half but progress made on enlarging natural gas portion of global portfolio',
#  'going with the flow – damen concept aim to tackle the next generation of offshore wind',
#  'lower oil & gas price take a bite out of norwegian energy giant ’ s profit',
#  'court fight on uk govt ’ s hand over oil & gas licensing round',
#  'net-zero puzzle need multiple piece in place : tripling renewables and slashing oil & gas emission',
#  'transocean ’ s plethora of new rig deal fetch $ 1.2 billion',
#  'europe redraws black gold map with pool of top oil producer',
#  'seavolt partner set to launch offshore solar platform in the north sea',
#  'iea : ensuring gas supply security and decarbonisation high on global energy market ’ s agenda',
#  'one of uk ’ s largest undeveloped oil field put on hiatus once again',
#  'propulsion fit for the future',
#  'a the offshore drilling market tightens , what ’ s up with the semi-sub rig fleet ?',
#  'ocean current energy is the third source',
#  'ithaca , aker solution , expro , proserv , and ey back 10-point plan to improve north sea worker ’ mental health',
#  'with salvage ops underway , dutch govt urged to step in for ‘ safe and environmentally sound ’ fso recycling',
#  'u spur zest far beyond it border for ccus a ‘ critical ’ decarbonisation tool',
#  '‘ first producing asset ’ on the horizon , a longboat snatch up stake in two north sea oil & gas field',
#  'what will two upcoming giant oil & gas development in the north sea bring ?',
#  'with carbon storage and renewables , totalenergies and petronas driving energy transition forward',
#  'bp , ørsted reach agreement on project overlap area in uk',
#  'woodmac pinpoint five global energy transition theme through asian lens',
#  'eni and vår energi scoop up neptune for $ 4.9 billion',
#  'searenergy and assc bring “ spirit of emden ” into service – offering cargo run in the german north sea',
#  'what are the key tool in uk and norway ’ s energy transition ?',
#  'all road lead valaris to ‘ strong and sustained upcycle ’',
#  'adnoc ’ s decarbonisation journey pick up speed with new net-zero target',
#  'viking and acorn picked a two new cluster to expand uk ’ s carbon capture and storage industry',
#  'north sea gas support both energy security and net-zero goal , say uk regulator',
#  'ficep : a single partner for all production technology in area 1. the mission is to enhance the productivity of wind tower and foundation fabricator',
#  'rapid development in offshore market require new production method for fast crew supplier',
#  'eni ’ s profit cut nearly in half but progress made on enlarging natural gas portion of global portfolio',
#  'going with the flow – damen concept aim to tackle the next generation of offshore wind',
#  'lower oil & gas price take a bite out of norwegian energy giant ’ s profit',
#  'court fight on uk govt ’ s hand over oil & gas licensing round',
#  'net-zero puzzle need multiple piece in place : tripling renewables and slashing oil & gas emission',
#  'transocean ’ s plethora of new rig deal fetch $ 1.2 billion',
#  'europe redraws black gold map with pool of top oil producer',
#  'seavolt partner set to launch offshore solar platform in the north sea',
#  'iea : ensuring gas supply security and decarbonisation high on global energy market ’ s agenda',
#  'one of uk ’ s largest undeveloped oil field put on hiatus once again',
#  'propulsion fit for the future',
#  'a the offshore drilling market tightens , what ’ s up with the semi-sub rig fleet ?',
#  'ocean current energy is the third source',
#  'ithaca , aker solution , expro , proserv , and ey back 10-point plan to improve north sea worker ’ mental health',
#  'with salvage ops underway , dutch govt urged to step in for ‘ safe and environmentally sound ’ fso recycling',
#  'u spur zest far beyond it border for ccus a ‘ critical ’ decarbonisation tool',
#  '‘ first producing asset ’ on the horizon , a longboat snatch up stake in two north sea oil & gas field',
#  'what will two upcoming giant oil & gas development in the north sea bring ?',
#  'with carbon storage and renewables , totalenergies and petronas driving energy transition forward',
#  'woodmac pinpoint five global energy transition theme through asian lens',
#  'eni and vår energi scoop up neptune for $ 4.9 billion',
#  'searenergy and assc bring “ spirit of emden ” into service – offering cargo run in the german north sea',
#  'what are the key tool in uk and norway ’ s energy transition ?',
#  "china , philippine ' dispute over grounded warship heat up",
#  'mol join gcmd a an impact partner',
#  'dry bulk stock and the dog day of summer',
#  'xiamen port ink cooperation agreement with psa in singapore',
#  'all road lead valaris to ‘ strong and sustained upcycle ’',
#  'adnoc ’ s decarbonisation journey pick up speed with new net-zero target',
#  'viking and acorn picked a two new cluster to expand uk ’ s carbon capture and storage industry',
#  'ficep : a single partner for all production technology in area 1. the mission is to enhance the productivity of wind tower and foundation fabricator',
#  'rapid development in offshore market require new production method for fast crew supplier',
#  'north sea gas support both energy security and net-zero goal , say uk regulator',
#  'eni ’ s profit cut nearly in half but progress made on enlarging natural gas portion of global portfolio',
#  'going with the flow – damen concept aim to tackle the next generation of offshore wind',
#  'lower oil & gas price take a bite out of norwegian energy giant ’ s profit',
#  'court fight on uk govt ’ s hand over oil & gas licensing round',
#  'net-zero puzzle need multiple piece in place : tripling renewables and slashing oil & gas emission',
#  'transocean ’ s plethora of new rig deal fetch $ 1.2 billion',
#  'europe redraws black gold map with pool of top oil producer',
#  'seavolt partner set to launch offshore solar platform in the north sea',
#  'iea : ensuring gas supply security and decarbonisation high on global energy market ’ s agenda',
#  'one of uk ’ s largest undeveloped oil field put on hiatus once again',
#  'propulsion fit for the future',
#  'ocean current energy is the third source',
#  'a the offshore drilling market tightens , what ’ s up with the semi-sub rig fleet ?',
#  'ithaca , aker solution , expro , proserv , and ey back 10-point plan to improve north sea worker ’ mental health',
#  'with salvage ops underway , dutch govt urged to step in for ‘ safe and environmentally sound ’ fso recycling',
#  'u spur zest far beyond it border for ccus a ‘ critical ’ decarbonisation tool',
#  '‘ first producing asset ’ on the horizon , a longboat snatch up stake in two north sea oil & gas field',
#  'what will two upcoming giant oil & gas development in the north sea bring ?',
#  'with carbon storage and renewables , totalenergies and petronas driving energy transition forward',
#  'bp , ørsted reach agreement on project overlap area in uk',
#  'woodmac pinpoint five global energy transition theme through asian lens',
#  'searenergy and assc bring “ spirit of emden ” into service – offering cargo run in the german north sea',
#  'eni and vår energi scoop up neptune for $ 4.9 billion',
#  "china , philippine ' dispute over grounded warship heat up",
#  'all road lead valaris to ‘ strong and sustained upcycle ’',
#  'adnoc ’ s decarbonisation journey pick up speed with new net-zero target',
#  'viking and acorn picked a two new cluster to expand uk ’ s carbon capture and storage industry',
#  'ficep : a single partner for all production technology in area 1. the mission is to enhance the productivity of wind tower and foundation fabricator',
#  'rapid development in offshore market require new production method for fast crew supplier',
#  'north sea gas support both energy security and net-zero goal , say uk regulator',
#  'eni ’ s profit cut nearly in half but progress made on enlarging natural gas portion of global portfolio',
#  'going with the flow – damen concept aim to tackle the next generation of offshore wind',
#  'lower oil & gas price take a bite out of norwegian energy giant ’ s profit',
#  'court fight on uk govt ’ s hand over oil & gas licensing round',
#  'net-zero puzzle need multiple piece in place : tripling renewables and slashing oil & gas emission',
#  'transocean ’ s plethora of new rig deal fetch $ 1.2 billion',
#  'europe redraws black gold map with pool of top oil producer',
#  'seavolt partner set to launch offshore solar platform in the north sea',
#  'iea : ensuring gas supply security and decarbonisation high on global energy market ’ s agenda',
#  'one of uk ’ s largest undeveloped oil field put on hiatus once again',
#  'propulsion fit for the future',
#  'ocean current energy is the third source',
#  'a the offshore drilling market tightens , what ’ s up with the semi-sub rig fleet ?',
#  'ithaca , aker solution , expro , proserv , and ey back 10-point plan to improve north sea worker ’ mental health',
#  'with salvage ops underway , dutch govt urged to step in for ‘ safe and environmentally sound ’ fso recycling',
#  'u spur zest far beyond it border for ccus a ‘ critical ’ decarbonisation tool',
#  '‘ first producing asset ’ on the horizon , a longboat snatch up stake in two north sea oil & gas field',
#  'what will two upcoming giant oil & gas development in the north sea bring ?',
#  'with carbon storage and renewables , totalenergies and petronas driving energy transition forward',
#  'bp , ørsted reach agreement on project overlap area in uk',
#  'woodmac pinpoint five global energy transition theme through asian lens',
#  'searenergy and assc bring “ spirit of emden ” into service – offering cargo run in the german north sea',
#  'eni and vår energi scoop up neptune for $ 4.9 billion',
#  'ukraine : russia ’ s attack on odesa ’ s port risk ‘ disastrous ’ global crisis',
#  'syria port authority shuts all port due to bad weather',
#  'port closed due to bad weather',
#  'hong kong and chinese port halt operation a typhoon talim hit',
#  'three port in kuwait suspend operation due to bad weather',
#  'typhoon muifa to shut china port for second time in 10 day',
#  'cyclone warning : india ’ s major west coast container port suspend operation',
#  "cyclone shutter already congested port on india 's busy west coast",
#  'port closure due to weather condition',
#  'la , long beach port close because of worker shortage during contract talk',
#  '',
#  'weather worry continue : what ’ s open , closed in south florida',
#  'india west coast port shut a cyclone nears ; shipping delay expected',
#  'china typhoon pose latest supply-chain threat a port shut',
#  'hurricane ian in florida : airport , port close ; evacuation continue',
#  'some west coast shipping port closed , hawaii resident stocking up',
#  'fuel truck unable to reach shipment at port everglades due to flood , leading to local gas station closure',
#  'closed port – bad weather',
#  'adani port suspends vessel operation at mundra and tuna port due to cyclone biparjoy',
#  'biparjoy cyclone : key port shut amidst alert',
#  'port of seattle operation shut down due to labor negotiation',
#  'alexandria , dekheila port closed over bad weather',
#  '2 long beach port terminal close amid labor negotiation',
#  'coastal cargo lay off it workforce , shuts down at port nola after 30+ year',
#  'port of seattle cargo operation continue after disruption amid labor negotiation',
#  'la-lb outlook darkens a labor unrest briefly shutter port',
#  'closure at long beach port resulting in trucking delay , container backlog']

# %%
X_title = vec_tdidf.fit_transform(X_title)
X_description = vec_tdidf.fit_transform(X_description)
print(X_title)
print(X_description)
# Out:
#   (0, 205)	0.3614197756567234
#   (0, 1486)	0.32254290507714056
#   (0, 740)	0.3614197756567234
#   (0, 605)	0.25789202949915646
#   (0, 734)	0.3614197756567234
#   (0, 970)	0.3614197756567234
#   (0, 1592)	0.16762273145912326
#   (0, 332)	0.3614197756567234
#   (0, 748)	0.13272102316080084
#   (0, 1085)	0.3614197756567234
#   (1, 296)	0.41857524137963104
#   (1, 1376)	0.41857524137963104
#   (1, 261)	0.39100656702652353
#   (1, 290)	0.39100656702652353
#   (1, 98)	0.17981572608874388
#   (1, 1091)	0.25105116523752585
#   (1, 912)	0.39100656702652353
#   (1, 273)	0.3091451848540163
#   (2, 792)	0.29395216293369897
#   (2, 234)	0.3396136009883741
#   (2, 1449)	0.1346346036418209
#   (2, 201)	0.28957564866294727
#   (2, 1100)	0.3305100911971378
#   (2, 863)	0.23546325902844853
#   (2, 569)	0.2445667688196849
#   :	:
#   (690, 91)	0.30551627058268105
#   (690, 67)	0.3139313551283826
#   (690, 246)	0.2808424058033664
#   (690, 999)	0.14316176744660106
#   (690, 1091)	0.20156396121150008
#   (691, 211)	0.3604622543931616
#   (691, 1510)	0.3604622543931616
#   (691, 370)	0.3604622543931616
#   (691, 832)	0.3604622543931616
#   (691, 820)	0.3122402422237401
#   (691, 818)	0.33912367407436267
#   (691, 1302)	0.33912367407436267
#   (691, 1029)	0.33912367407436267
#   (691, 1091)	0.19431748458174095
#   (692, 1475)	0.36555271907901127
#   (692, 1195)	0.36555271907901127
#   (692, 158)	0.3285590233913023
#   (692, 869)	0.3285590233913023
#   (692, 288)	0.3285590233913023
#   (692, 140)	0.3285590233913023
#   (692, 390)	0.30691909865090256
#   (692, 322)	0.2852791739105029
#   (692, 121)	0.26565347392309707
#   (692, 1091)	0.19706164511741686
#   (692, 748)	0.12629208753110321
#   (0, 9425)	0.38723642537015696
#   (0, 10299)	0.36994849809480723
#   (0, 4772)	0.16863981818077817
#   (0, 8887)	0.21029371043241488
#   (0, 7950)	0.18699138143139418
#   (0, 14901)	0.09724486167981042
#   (0, 5628)	0.18218130585946538
#   (0, 10489)	0.38723642537015696
#   (0, 8631)	0.27400179048507056
#   (0, 12191)	0.38723642537015696
#   (0, 13682)	0.0637532694783378
#   (0, 9683)	0.06468066232461757
#   (0, 5166)	0.38723642537015696
#   (0, 8086)	0.1575956190157825
#   (0, 13721)	0.0699520083540276
#   (1, 2916)	0.35200849891937613
#   (1, 3139)	0.35200849891937613
#   (1, 15055)	0.07747541132007593
#   (1, 14281)	0.2671848574963265
#   (1, 9052)	0.44090962347796514
#   (1, 3641)	0.19895713506616514
#   (1, 13109)	0.20306376050773814
#   (1, 7521)	0.11109044081686037
#   (1, 5114)	0.24314108282293467
#   (1, 6534)	0.0783816923746982
#   :	:
#   (691, 6534)	0.08405491291063925
#   (691, 10538)	0.16999122714189305
#   (691, 4772)	0.10295607354465354
#   (691, 13682)	0.23353154807440415
#   (691, 9683)	0.07897621213124933
#   (692, 14084)	0.36495016350175286
#   (692, 2712)	0.3433459087390697
#   (692, 8022)	0.298199634819001
#   (692, 2851)	0.26126691736096075
#   (692, 4450)	0.29108472858567236
#   (692, 12512)	0.11672170615776685
#   (692, 4456)	0.21244452053264037
#   (692, 3130)	0.24787621906030613
#   (692, 2100)	0.45656573784227555
#   (692, 8151)	0.14504551348052866
#   (692, 8387)	0.2044406680274219
#   (692, 13643)	0.1923847985029325
#   (692, 7296)	0.08132609476207539
#   (692, 7197)	0.059118796313720946
#   (692, 1835)	0.06480888334124339
#   (692, 13833)	0.05768206371528305
#   (692, 6534)	0.061037527792227736
#   (692, 10538)	0.12344125871784553
#   (692, 13682)	0.16958185860126193
#   (692, 9683)	0.11469913122177175

# %%
# Split the data into training and testing sets
X_train_title, X_test_title, X_train_description, X_test_description, y_train, y_test = train_test_split(
    X_title, X_description, y, test_size=0.2, random_state=42
)

# %%
# Concatenate the vectors to create a feature matrix
X_train = np.hstack((X_train_title.toarray(), X_train_description.toarray()))
X_test = np.hstack((X_test_title.toarray(), X_test_description.toarray()))

# %%
! pip install tensorflow
! pip install tensorflow_hub
! pip install tensorflow_text
# Out:
# Requirement already satisfied: tensorflow in c:\users\dishan\anaconda3\lib\site-packages (2.13.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: setuptools in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (63.4.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.58.0)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.24.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.3.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.4.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Using cached protobuf-4.24.3-cp39-cp39-win_amd64.whl (430 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.31.0)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.5.26)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.14.1)
# Collecting tensorboard<2.14,>=2.13
#   Using cached tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
# Collecting keras<2.14,>=2.13.1
#   Using cached keras-2.13.1-py3-none-any.whl (1.7 MB)
# Collecting tensorflow-estimator<2.14,>=2.13.0
#   Using cached tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.7.0)
# Requirement already satisfied: packaging in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (21.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (16.0.6)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\dishan\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\dishan\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.23.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.28.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dishan\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.3)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dishan\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.3.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dishan\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.13.0->tensorflow) (3.0.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\dishan\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.26.11)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dishan\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dishan\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dishan\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (5.3.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\dishan\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dishan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dishan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dishan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\dishan\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\dishan\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.2.2)
# Installing collected packages: tensorflow-estimator, tensorboard-data-server, protobuf, keras, google-auth-oauthlib, tensorboard
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.10.0
#     Uninstalling tensorflow-estimator-2.10.0:
#       Successfully uninstalled tensorflow-estimator-2.10.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.6.1
#     Uninstalling tensorboard-data-server-0.6.1:
#       Successfully uninstalled tensorboard-data-server-0.6.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: keras
#     Found existing installation: keras 2.10.0
#     Uninstalling keras-2.10.0:
#       Successfully uninstalled keras-2.10.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 0.4.6
#     Uninstalling google-auth-oauthlib-0.4.6:
#       Successfully uninstalled google-auth-oauthlib-0.4.6
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.10.1
#     Uninstalling tensorboard-2.10.1:
#       Successfully uninstalled tensorboard-2.10.1
# Successfully installed google-auth-oauthlib-1.0.0 keras-2.13.1 protobuf-4.24.3 tensorboard-2.13.0 tensorboard-data-server-0.7.1 tensorflow-estimator-2.13.0
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# Requirement already satisfied: tensorflow_hub in c:\users\dishan\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow_hub) (4.24.3)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow_hub) (1.24.3)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# Collecting tensorflow_text
#   Using cached tensorflow_text-2.10.0-cp39-cp39-win_amd64.whl (5.0 MB)
# Collecting tensorflow<2.11,>=2.10.0
#   Using cached tensorflow-2.10.1-cp39-cp39-win_amd64.whl (455.9 MB)
# Requirement already satisfied: tensorflow-hub>=0.8.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow_text) (0.14.0)
# Collecting keras<2.11,>=2.10.0
#   Using cached keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (23.5.26)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (2.3.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (3.7.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (16.0.6)
# Requirement already satisfied: numpy>=1.20 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.24.3)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.6.3)
# Collecting tensorboard<2.11,>=2.10
#   Using cached tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.58.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (4.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (0.2.0)
# Requirement already satisfied: setuptools in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (63.4.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.1.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.4.0)
# Requirement already satisfied: packaging in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (21.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (3.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (0.31.0)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Using cached tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.16.0)
# Collecting protobuf<3.20,>=3.9.2
#   Using cached protobuf-3.19.6-cp39-cp39-win_amd64.whl (895 kB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.14.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\dishan\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.11,>=2.10.0->tensorflow_text) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dishan\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (3.3.4)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dishan\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (2.28.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dishan\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\dishan\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dishan\anaconda3\lib\site-packages (from packaging->tensorflow<2.11,>=2.10.0->tensorflow_text) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dishan\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (5.3.1)
# Requirement already satisfied: urllib3<2.0 in c:\users\dishan\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (1.26.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dishan\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dishan\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\dishan\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dishan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dishan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dishan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (2022.9.14)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\dishan\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\dishan\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (3.2.2)
# Installing collected packages: keras, tensorflow-estimator, tensorboard-data-server, protobuf, google-auth-oauthlib, tensorboard, tensorflow, tensorflow_text
#   Attempting uninstall: keras
#     Found existing installation: keras 2.13.1
#     Uninstalling keras-2.13.1:
#       Successfully uninstalled keras-2.13.1
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.13.0
#     Uninstalling tensorflow-estimator-2.13.0:
#       Successfully uninstalled tensorflow-estimator-2.13.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.1
#     Uninstalling tensorboard-data-server-0.7.1:
#       Successfully uninstalled tensorboard-data-server-0.7.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.24.3
#     Uninstalling protobuf-4.24.3:
#       Successfully uninstalled protobuf-4.24.3
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.13.0
#     Uninstalling tensorboard-2.13.0:
#       Successfully uninstalled tensorboard-2.13.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.13.0
#     Uninstalling tensorflow-2.13.0:
#       Successfully uninstalled tensorflow-2.13.0
#   Rolling back uninstall of tensorflow
#   Moving to c:\users\dishan\anaconda3\lib\site-packages\tensorflow-2.13.0.dist-info\
#    from C:\Users\Dishan\anaconda3\Lib\site-packages\~ensorflow-2.13.0.dist-info
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Dishan\\anaconda3\\Lib\\site-packages\\tensorflow\\compiler\\tf2tensorrt\\_pywrap_py_utils.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dishan\anaconda3\lib\site-packages)

# %%
bert_preprocess = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
bert_encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3440\1416483565.py in <module>
#       1 import tensorflow as tf
#       2 import tensorflow_hub as hub
# ----> 3 import tensorflow_text as text
#       4
#       5 bert_preprocess = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
#
# ModuleNotFoundError: No module named 'tensorflow_text'

# %%
# Bert layers
text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
preprocessed_text = bert_preprocess(text_input)
outputs = bert_encoder(preprocessed_text)

# Neural network layers
l = tf.keras.layers.Dropout(0.1, name="dropout")(outputs['pooled_output'])
l = tf.keras.layers.Dense(1, activation='sigmoid', name="output")(l)

# Use inputs and outputs to construct a final model
model = tf.keras.Model(inputs=[text_input], outputs = [l])

# %%
model.summary()

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall')
]

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=METRICS)

# %%
model.fit(X_train, y_train, epochs=10)

# %%
model.evaluate(X_test, y_test)

# %%
 y_predicted = model.predict(X_test)
 y_predicted = y_predicted.flatten()

# %%
y_predicted = np.where(y_predicted > 0.5, 1, 0)
y_predicted

# %%
cm = confusion_matrix(y_test, y_predicted)
cm

# %%
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
